# %% [markdown]
# # Summary Table for Selected Experiments
#
# ### This script filters and summarizes experiments from the DARPA RAM dataset according to different criteria.

# %%
# from imports import * 
from cmlreaders import CMLReader, get_data_index
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy
from scipy import stats
pd.set_option('display.max_columns', None)

# %% [markdown]
# Load data from all DARPA RAM experiments

# %%
df1 = get_data_index("r1")
df2 = get_data_index("pyfr")
df = pd.concat([df1,df2])
assert len(df) == len(df1)+len(df2)

# %%
df
# Out:
#     Recognition                                         all_events  \
# 0           NaN  protocols/r1/subjects/FBG490/experiments/EFRCo...
# 1           NaN  protocols/r1/subjects/FBG490/experiments/EFRCo...
# 2           NaN  protocols/r1/subjects/FBG490/experiments/EFRCo...
# 3           NaN  protocols/r1/subjects/FBG490/experiments/EFRCo...
# 4           NaN  protocols/r1/subjects/FBG491/experiments/EFRCo...
# ..          ...                                                ...
# 373         NaN                                                NaN
# 374         NaN                                                NaN
# 375         NaN                                                NaN
# 376         NaN                                                NaN
# 377         NaN                                                NaN
#
#                                               contacts          experiment  \
# 0    protocols/r1/subjects/FBG490/localizations/0/m...  EFRCourierOpenLoop
# 1    protocols/r1/subjects/FBG490/localizations/0/m...  EFRCourierOpenLoop
# 2    protocols/r1/subjects/FBG490/localizations/0/m...  EFRCourierOpenLoop
# 3    protocols/r1/subjects/FBG490/localizations/0/m...  EFRCourierReadOnly
# 4    protocols/r1/subjects/FBG491/localizations/0/m...  EFRCourierOpenLoop
# ..                                                 ...                 ...
# 373                                                NaN                pyFR
# 374                                                NaN                pyFR
# 375                                                NaN                pyFR
# 376                                                NaN                pyFR
# 377                                                NaN                pyFR
#
#     import_type  localization math_events  montage original_experiment  \
# 0         build             0         NaN        0                 NaN
# 1         build             0         NaN        0                 NaN
# 2         build             0         NaN        0                 NaN
# 3         build             0         NaN        0                 NaN
# 4         build             0         NaN        0                 NaN
# ..          ...           ...         ...      ...                 ...
# 373         NaN             0         NaN        0                 NaN
# 374         NaN             0         NaN        0                 NaN
# 375         NaN             0         NaN        0                 NaN
# 376         NaN             0         NaN        0                 NaN
# 377         NaN             0         NaN        0                 NaN
#
#     original_session                                              pairs  \
# 0                NaN  protocols/r1/subjects/FBG490/localizations/0/m...
# 1                NaN  protocols/r1/subjects/FBG490/localizations/0/m...
# 2                NaN  protocols/r1/subjects/FBG490/localizations/0/m...
# 3                NaN  protocols/r1/subjects/FBG490/localizations/0/m...
# 4                NaN  protocols/r1/subjects/FBG491/localizations/0/m...
# ..               ...                                                ...
# 373              NaN                                                NaN
# 374              NaN                                                NaN
# 375              NaN                                                NaN
# 376              NaN                                                NaN
# 377              NaN                                                NaN
#
#     ps4_events  session subject subject_alias  system_version  \
# 0          NaN        0  FBG490        FBG490             4.0
# 1          NaN        1  FBG490        FBG490             4.0
# 2          NaN        2  FBG490        FBG490             4.0
# 3          NaN        0  FBG490        FBG490             4.0
# 4          NaN        1  FBG491        FBG491             4.0
# ..         ...      ...     ...           ...             ...
# 373        NaN        2   UP045           NaN             NaN
# 374        NaN        3   UP045           NaN             NaN
# 375        NaN        0   UP046           NaN             NaN
# 376        NaN        1   UP046           NaN             NaN
# 377        NaN        2   UP046           NaN             NaN
#
#                                            task_events
# 0    protocols/r1/subjects/FBG490/experiments/EFRCo...
# 1    protocols/r1/subjects/FBG490/experiments/EFRCo...
# 2    protocols/r1/subjects/FBG490/experiments/EFRCo...
# 3    protocols/r1/subjects/FBG490/experiments/EFRCo...
# 4    protocols/r1/subjects/FBG491/experiments/EFRCo...
# ..                                                 ...
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
#
# [3781 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Recognition', 'all_events', 'contacts', 'experiment', 'import_type',
#        'localization', 'math_events', 'montage', 'original_experiment',
#        'original_session', 'pairs', 'ps4_events', 'session', 'subject',
#        'subject_alias', 'system_version', 'task_events'],
#       dtype='object')

# %%
exp_types = df.experiment.unique()
exp_types
# Out:
# array(['EFRCourierOpenLoop', 'EFRCourierReadOnly', 'FR1', 'FR2', 'PAL1',
#        'YC1', 'PAL2', 'catFR1', 'YC2', 'catFR2', 'PS1', 'ICatFR1',
#        'ICatFR6', 'IFR1', 'IFR6', 'PS3', 'PS2', 'TH1', 'FR3', 'PS2.1',
#        'PAL3', 'TH3', 'OPS', 'RepFR1', 'catFR3', 'FR5', 'PS4_catFR',
#        'THR', 'PS4_FR', 'PAL5', 'THR1', 'catFR5', 'PS4_catFR5', 'FR6',
#        'PS5_catFR', 'catFR6', 'TICL_FR', 'LocationSearch', 'TICL_catFR',
#        'DBOY1', 'CatFR6', 'RepFR2', 'CPS', 'pyFR'], dtype=object)

# %% [markdown]
# ## Count all verbal memory stimulation experiments

# %%
import pandas as pd
import re

# --- Step 1: Define experiment types from the dataframe ---
exp_types = df['experiment'].unique()

# --- Step 2: Function to filter experiments ---
def exp_filter(exp_name):
    # Convert to upper case for case-insensitive matching
    exp_upper = exp_name.upper()
    
    # Exclude unwanted substrings
    exclude_keywords = ['YC', 'THR', 'TH', 'COURIER', 'DBOY']
    if any(k in exp_upper for k in exclude_keywords):
        return False
    
    # Include only experiments with a number > 1
    match = re.search(r'(\d+)', exp_name)
    if match:
        num = int(match.group(1))
        return num > 1
    return False

# --- Step 3: Apply filtering to the dataframe ---
df_filtered = df[df['experiment'].apply(exp_filter)].copy()

# --- Step 4: Create summary table ---
summary_filtered = (
    df_filtered.groupby('experiment')
        .agg(
            total_rows=('experiment', 'size'),
            n_subjects=('subject', pd.Series.nunique),
            total_sessions=('session', 'count')
        )
        .sort_index()
)

# --- Step 5: Compute overall totals ---
n_subjects_total = df_filtered['subject'].nunique()
n_sessions_total = df_filtered['session'].count()

# --- Step 6: Print results ---
print("\nSummary Table (Experiments with number >1, excluding YC/THR/Courier/DBOY):")
print(summary_filtered)
print(f"\nTotal unique subjects: {n_subjects_total}")
print(f"Total sessions: {n_sessions_total}")
# Out:
# Summary Table (Experiments with number >1, excluding YC/THR/Courier/DBOY):
#             total_rows  n_subjects  total_sessions
# experiment
# CatFR6               1           1               1
# FR2                 79          38              79
# FR3                 32          18              32
# FR5                 24          16              24
# FR6                  9           5               9
# ICatFR6              8           5               8
# IFR6                11           7              11
# PAL2                26          20              26
# PAL3                15           9              15
# PAL5                 4           4               4
# PS2                158          53             158
# PS2.1              141          38             141
# PS3                 45          24              45
# PS4_FR               9           5               9
# PS4_catFR            7           4               7
# PS4_catFR5           5           3               5
# PS5_catFR            1           1               1
# RepFR2              89          39              89
# catFR2              26          19              26
# catFR3              13           9              13
# catFR5              44          27              44
# catFR6              70          23              70
#
# Total unique subjects: 260
# Total sessions: 817
